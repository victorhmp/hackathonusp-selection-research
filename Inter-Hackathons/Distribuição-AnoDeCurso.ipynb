# %% [markdown]
# # Ano de curso
#
# Neste Notebook, criamos algumas visualizações para observar a distribuição dos inscritos quanto ao ano de estudo em que estavam quando se inscreveram.

# %%
# Importanto bibliotecas necessárias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

subs_2016_1 = pd.read_csv('./2016.1/2016.1 - Inscritos.csv', sep=';')
subs_2016_2 = pd.read_csv('./2016.2/2016.2 - Inscritos.csv', sep=';')
subs_2017_1 = pd.read_csv('./2017.1/2017.1 - Inscritos.csv', sep=';')
subs_2017_2 = pd.read_csv('./2017.2/2017.2 - Inscritos.csv', sep=';')
subs_2018_1 = pd.read_csv('./2018.1/2018.1 - Inscritos.csv', sep=';')

# %% [markdown]
# ## 2016.1

# %%
subs_2016_1['Em que ano você está?'].value_counts().plot(kind='pie', 
                                          title='Distribuição de inscritos por institutos/faculdades (2016.1)',
                                          autopct='%1.1f%%',
                                          figsize=(12, 12),
                                          fontsize='12',
                                          legend=True,
                                          label='')

# %% [markdown]
# ## 2016.2

# %%
subs_2016_2['Em que ano você está?'].value_counts().plot(kind='pie', 
                                          title='Distribuição de inscritos por institutos/faculdades (2016.1)',
                                          autopct='%1.1f%%',
                                          figsize=(12, 12),
                                          fontsize='12',
                                          legend=True,
                                          label='')

# %% [markdown]
# ## 2017.1

# %%
subs_2017_1['Em que ano você está?'].value_counts().plot(kind='pie', 
                                          title='Distribuição de inscritos por institutos/faculdades (2016.1)',
                                          autopct='%1.1f%%',
                                          figsize=(12, 12),
                                          fontsize='12',
                                          legend=True,
                                          label='')

# %% [markdown]
# ## 2017.2

# %%
subs_2017_2['Em que ano você está?'].value_counts().plot(kind='pie', 
                                          title='Distribuição de inscritos por institutos/faculdades (2016.1)',
                                          autopct='%1.1f%%',
                                          figsize=(12, 12),
                                          fontsize='12',
                                          legend=True,
                                          label='')

# %% [markdown]
# ## 2018.1

# %%
subs_2018_1['Em que ano você está?'].value_counts().plot(kind='pie', 
                                          title='Distribuição de inscritos por institutos/faculdades (2016.1)',
                                          autopct='%1.1f%%',
                                          figsize=(12, 12),
                                          fontsize='12',
                                          legend=True,
                                          label='')
